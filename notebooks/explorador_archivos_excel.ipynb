# %% [markdown]
# ## 🔍 Explorador de archivos Excel (INDEC)
#
# **Objetivo:** inspeccionar la estructura interna de los archivos Excel oficiales antes de procesarlos. Los archivos del INDEC suelen tener hojas ocultas, filas de título, celdas combinadas y encabezados desplazados.
#
# **Script:** `src/explorar_excel.py`
#
# ---
#
# ### ¿Qué hace?
#
# | Función | Descripción |
# |:--------|:------------|
# | `listar_hojas()` | Muestra todos los nombres de hojas del archivo |
# | `resumen_hojas()` | Muestra dimensiones y primeras 8 filas de cada hoja |
# | `buscar_texto_en_archivo()` | Busca una palabra (ej. "Chaco") y dice en qué fila/columna está |
# | `explorar()` | Función unificada para usar desde notebook |
#
# ---
#
# ### Uso típico
#
# 1. **Ver estructura:** listar hojas y ver primeras filas
# 2. **Buscar "Chaco":** encontrar exactamente en qué fila y columna está
# 3. **Ajustar el script de análisis:** usar esos índices para leer bien la tabla
#
# ---

# %%
import os
os.chdir('..')  # para en la raíz del proyecto, para que las rutas relativas funcionen

# %%
# %run src/explorar_excel.py data/raw/opex_anexo_cuadros_10_03_26.xls --buscar Chaco
# Out:
# 📁 Explorando: opex_anexo_cuadros_10_03_26.xls
#
# El archivo tiene 20 hoja(s): ['Índice', 'cuadro1', 'cuadro2', 'cuadro3', 'cuadro4', 'cuadro5', 'OP-Regiones 2022-2025', 'OP-Rubros 2022-2025', 'OP-Zonas 2022', 'OP-Zonas 2023', 'OP-Zonas 2024', 'OP-Zonas 2025', 'Complejos-regiones 2022', 'Complejos-regiones 2023', 'Complejos-regiones 2024', 'Complejos-regiones 2025', 'Prov-subrubros 2025 y 2024', 'Region-país 2025 y 2024', 'Region-país 2015-2025 anual', 'Region-país 2015-2025 semestre']
#
# ...
# Hoja: Índice — 27 filas x 1 columnas
# ...
#                                                                                                                                                           0
# 0                                                                                          Origen provincial de las exportaciones. Bienes- Anexo de cuadros
# ...
