# %% [markdown]
# ## Fase 4.1 — Precio implícito por año
#
# **Objetivo:** calcular el precio implícito (`FOB_dólar / Peso neto`, expresado
# en USD/tonelada) de las exportaciones de Chaco, año a año, como primer paso
# para responder el objetivo #4 (causas del descenso 2022-2024 y la
# recuperación 2026).
#
# **Script:** `src/fase4_precio_implicito.py`
#
# ---
#
# ### Qué es (y qué no es) el precio implícito
#
# Es un promedio ponderado de **todos los rubros de Chaco juntos** (PP/MOA/MOI/CyE)
# — no el precio internacional de ningún commodity puntual (eso se compara en
# la Fase 4.4, contra el precio de la soja). Un cambio en la **composición**
# de lo exportado puede mover este número tanto como un cambio real de
# precios internacionales — ese matiz se retoma en la Fase 4.6.

# %%
# %run ../src/fase4_precio_implicito.py
# Out:
# ...
# FASE 4.1 — PRECIO IMPLÍCITO POR AÑO (USD/tonelada)
# Provincia: Chaco
# ...
#
# Año         FOB (M USD)      Toneladas      USD/tonelada
# --------------------------------------------------------
# 2002              137.6        712,210             193.2
# 2003              198.5      1,012,656             196.1
# 2004              152.9        678,545             225.4
# 2005              151.6        601,136             252.1
# 2006              192.2        824,775             233.0
# 2007              293.0      1,131,216             259.0
# 2008              391.5      1,150,633             340.3
# 2009              169.8        472,189             359.6
# 2010              373.7      1,051,633             355.3
# 2011              590.0      1,231,839             478.9
# 2012              305.0        687,726             443.5
# 2013              282.5        618,437             456.9
# 2014              405.3      1,069,208             379.1
# ...

# %% [markdown]
# ### 📌 Conclusión parcial — Fase 4.1
#
# El precio implícito **no bajó** entre 2022 y 2024 — subió (+15,1% en 2024
# respecto a 2023, y por encima del nivel de 2022). La caída de valor total
# en ese período (USD 516,6M → USD 216,1M) se explica casi enteramente por
# una baja de **volumen** (-63% en toneladas), no de precio. Esto matiza la
# hipótesis dominante original — el componente de precio internacional no se
# sostiene con este primer corte de los datos propios de Chaco.
#
# > **Nota:** 2026 es un año parcial (6 de 12 meses) — el precio implícito
# > de 2026 no es directamente comparable a años completos sin ese matiz.

# %% [markdown]
# ## Fase 4.2 — Gráfico del precio implícito por año
#
# **Objetivo:** visualizar la serie de precio implícito (USD/tonelada)
# calculada en la Fase 4.1, para poder leer de un vistazo si la ventana
# 2022→2024 —la que la hipótesis dominante original atribuía a una caída
# de precio internacional— muestra o no una caída de precio en los datos
# propios de Chaco.
#
# **Script:** `src/fase4_grafico_precio_implicito.py`
#
# **Ventana:** 2015-2026, la misma que la tabla resumen de la Fase 1.9,
# para que este gráfico sea comparable con los anteriores del proyecto.
# 2022 y 2024 quedan marcados con línea vertical punteada (pico previo y
# piso), y 2026 se distingue con marcador y línea distintos por ser un
# año parcial (6 de 12 meses) — mismo criterio de la Fase 4.1.
#
# ---

# %%
# %run ../src/fase4_grafico_precio_implicito.py

# %% [markdown]
# ###  Conclusión parcial — Fase 4.2
#
# El gráfico confirma visualmente, y de forma más contundente que la tabla
# de la Fase 4.1, el hallazgo clave del objetivo #4 hasta acá:
#
# - **En la ventana 2022→2024 (marcada con las líneas punteadas) el precio
#   implícito no cae — sube:** de USD 398,2/ton (2022) a USD 447,6/ton
#   (2024), +12,4%. 2024 es, de hecho, el valor más alto de toda la serie
#   2015-2026. Esto va en contra de la lectura intuitiva más simple
#   ("si el valor total exportado se derrumbó, debe haber sido por precio")
#   y refuerza que la explicación pasa por volumen (-63% en toneladas en el
#   mismo período, ver Fase 4.1), no por precio.
# - **2015-2021 es volátil sin tendencia clara** (335 → 282 → 262 → 338 →
#   255 → 261 → 367 USD/ton): hay saltos de hasta +30% año a año en ambas
#   direcciones que no coinciden con ningún quiebre evidente en la política
#   comercial conocida hasta ahora. Vale como advertencia para no
#   sobre-interpretar dos años puntuales (2022 y 2024) fuera de este
#   contexto más ruidoso — motivo por el cual en la Fase 4.9 conviene mirar
#   la serie completa y no solo el par de años del pico y el piso.
# - **2025-2026 se mantiene en niveles altos:** -4,5% en 2025 y +4,2% en
#   2026 (parcial), siempre por encima de todo el rango 2015-2021 y del
#   propio 2022. La recuperación del valor total exportado en 2026 no viene
#   entonces de un precio que "vuelve a subir" desde un piso — el precio ya
#   estaba arriba desde 2024. Si hay recuperación de valor en 2026, hay que
#   mirar volumen para confirmarlo (dato ya disponible en la Fase 1, pendiente
#   de cruzar acá explícitamente en la Fase 4.9).
#
# **Qué NO responde todavía este gráfico** (para eso siguen la Fase 4.4 y
# 4.5): que el precio implícito *en dólares nominales* no haya caído no
# descarta un efecto de tipo de cambio real —si el peso se apreció en
# términos reales en el mismo período, una parte de esta suba nominal en
# USD podría no traducirse en más poder de compra real para el exportador—
# ni dice nada todavía sobre si el precio de Chaco se movió en línea con el
# precio internacional de sus commodities principales (soja) o distinto a
# él. Ambas preguntas quedan abiertas para 4.4 (soja) y 4.5 (ITCRM).
