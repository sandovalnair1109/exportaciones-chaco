# %%
import os
os.chdir('..')

# %%
# %run src/chequeo_calidad_chaco.py
# Out:
# ...
# PASO 1 (Fase 1.2) — CHEQUEO DE CALIDAD
# Provincia: Chaco
# Fuente: chaco_serie_mensual_2002_2026.csv
# ...
# ESTRUCTURA DEL DATASET
# ...
# Filas: 884 | Columnas: 7
#
# Columnas y tipos de dato:
# Año                int64
# Mes                int64
# FOB_dólar        float64
# Peso neto        float64
# Nombre Prov          str
# Nombre_Región        str
# Rubro                str
# dtype: object
#
# Primeras filas:
#     Año  Mes   FOB_dólar     Peso neto Nombre Prov  Nombre_Región  \
# 0  2002    1   371738.00  5.458400e+05       Chaco  Noreste (NEA)
# 1  2002    1  5320346.98  3.130487e+07       Chaco  Noreste (NEA)
# 2  2002    1  3707194.68  5.095130e+06       Chaco  Noreste (NEA)
# 3  2002    2   433306.00  4.906900e+05       Chaco  Noreste (NEA)
# 4  2002    2  3760375.56  2.489178e+07       Chaco  Noreste (NEA)
#
#                                        Rubro
# 0    Manufacturas de origen industrial (MOI)
# 1                   Productos primarios (PP)
# ...
