# %% [markdown]
# ## Fase 4.6 — Composición por Rubro (PP/MOA/MOI/CyE)
#
# **Objetivo:** ya sabemos que la caída/recuperación de Chaco es de volumen,
# no de precio (Fase 4.3). Este paso mira si ese volumen se concentra en
# algún Rubro en particular, o si todos se movieron parejo.
#
# **Script:** `src/fase4_composicion_rubro.py`
#
# ⚠️ **Aclaración:** no se compara el FOB absoluto
# de 2022 (año completo) contra 2026 (parcial, solo H1) — eso exagera
# artificialmente cualquier caída. Se consideró esto para comparar primer
# semestre contra primer semestre en los tres años de foco (2022/2024/2026),
# mismo criterio ya usado en la Fase 1.11 y la Fase 4.3.

# %%
# %run ../src/fase4_composicion_rubro.py
# Out:
# ...
# FASE 4.6 — COMPOSICIÓN POR RUBRO (% del total FOB de Chaco, por año)
# ...
#
# Año           PP       MOA       MOI       CyE
# ----------------------------------------------
# 2015       76.1%     22.1%      1.7%      0.0%
# 2016       80.6%     18.1%      1.3%      0.0%
# 2017       79.3%     18.0%      2.7%      0.0%
# 2018       78.6%     20.0%      1.5%      0.0%
# 2019       86.7%     12.3%      1.0%      0.0%
# 2020       86.6%     12.5%      0.9%      0.0%
# 2021       82.6%     16.5%      1.0%      0.0%
# 2022       89.4%     10.0%      0.6%      0.0%
# 2023       77.9%     20.8%      1.2%      0.0%
# 2024       65.1%     32.6%      2.2%      0.0%
# 2025       64.8%     33.6%      1.7%      0.0%
# 2026       65.4%     33.2%      1.5%      0.0%  (parcial)
#
# ...
# 📊 COMPARACIÓN DIRECTA — 2022 (pico) vs. 2024 (piso) vs. 2026 (recuperación)
# ...
#
# Rubro           2022        2024        2026    Δ pp (22→26)
# ------------------------------------------------------------
# ...

# %% [markdown]
# ###  Conclusión parcial — Fase 4.6
#
# La composición cambió de raíz entre 2022 y 2026: Productos Primarios pasó
# de representar el 89,4% al 65,4% del total (-24 puntos porcentuales),
# mientras que MOA (manufacturas de origen agropecuario) pasó de 10,0% a
# 33,2% (+23,1 puntos).
#
# En términos absolutos (primer semestre, para comparar años iguales): PP
# cayó -48,3% (192,2M → 99,3M USD) mientras MOA creció +87,2% (26,9M →
# 50,4M USD).
#
# **La caída de Chaco no fue un fenómeno parejo — se concentró en
# Productos Primarios**, y la recuperación de 2026 se sostiene en una
# estructura distinta a la de 2022, con mucho más peso de manufacturas
# agropecuarias. Esto conecta con la nota de contexto sobre el algodón
# (fuentes.md) y deja como pregunta abierta para el cierre del proyecto:
# ¿la caída de PP es volumen físico real (menos cosecha/menos exportado en
# bruto) o un desplazamiento hacia vender más procesado y menos crudo?
