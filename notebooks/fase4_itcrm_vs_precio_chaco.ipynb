# %% [markdown]
# ## Fase 4.5 — Efecto del tipo de cambio real (ITCRM)
#
# **Objetivo:** evaluar si la apreciación cambiaria real (medida por el ITCRM
# del BCRA) explica parte de la caída del precio implícito de Chaco entre
# 2022 y 2024, más allá del precio internacional puntual (Fase 4.4).
#
# **Script:** `src/fase4_itcrm_vs_precio_chaco.py`
#
# **Fuente adicional:** `data/raw/ITCRM_serie_historica.xlsx`, hoja
# `ITCRM y bilaterales prom. mens.`.
#
# **Nota:** el archivo ya trae una hoja de promedios mensuales precalculada —
# no hizo falta el `resample('MS').mean()` sobre la serie diaria que estaba
# anotado como pendiente en `docs/inventario_datasets.md`. Esa hoja mensual
# trae 3 filas de pie de página (notas/fuente) que el script descarta antes
# de operar con fechas.
#
# El promedio anual de ITCRM se recorta a los mismos meses que tiene
# disponibles la serie de Chaco cada año (relevante para 2026, parcial).

# %%
# %run ../src/fase4_itcrm_vs_precio_chaco.py
# Out:
# ...
# FASE 4.5 — ITCRM vs. PRECIO IMPLÍCITO DE CHACO
# ...
#
# Año     Precio Chaco (USD/ton)   ITCRM (prom.)   Δ% Precio    Δ% ITCRM   ¿Misma dir.?
# ------------------------------------------------------------------------------------------
# 2015                     335.4            82.7      -11.5%      -21.7%           ✅ sí
# 2016                     281.7            94.0      -16.0%      +13.7%           ❌ no
# 2017                     261.6            88.0       -7.1%       -6.4%           ✅ sí
# 2018                     338.2           109.3      +29.3%      +24.1%           ✅ sí
# 2019                     255.3           121.2      -24.5%      +10.9%           ❌ no
# 2020                     261.1           117.6       +2.3%       -3.0%           ❌ no
# 2021                     367.2           113.5      +40.7%       -3.5%           ❌ no
# 2022                     398.2            95.2       +8.4%      -16.1%           ❌ no
# ...

# %% [markdown]
# ### 📌 Conclusión parcial — Fase 4.5
#
# El ITCRM prácticamente no se movió entre 2022 y 2024 (+0,2%), mientras el
# precio implícito de Chaco subió +12,4% en el mismo período — no hay
# apreciación real que explicar, y mucho menos que explique una caída de
# precio que ni siquiera ocurrió (ver Fase 4.1).
#
# En la serie completa (2015-2025), la correlación entre ambas variables es
# débil y de signo contrario al esperado por la hipótesis (-0,64, con
# coincidencia direccional en solo 36% de los años).
#
# **Con esto, los tres factores de precio analizados (implícito propio,
# precio internacional de la soja, tipo de cambio real) quedan descartados
# como explicación de la caída 2022-2024.** El eje explicativo pasa por
# volumen/composición, no por precio — pendiente cerrar con la Fase 4.6
# (composición por Rubro) y la Fase 4.8 (retenciones).
