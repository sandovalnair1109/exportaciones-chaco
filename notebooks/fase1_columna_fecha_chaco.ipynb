# %% [markdown]
# ## Paso 2 (Fase 1.3) — Columna de fecha persistente
#
# **Objetivo:** agregar una columna `fecha` (tipo `datetime`, a partir de
# `Año` + `Mes`) a `data/processed/chaco_serie_mensual_2002_2026.csv`,
# de forma **persistente** — a diferencia del chequeo de la Fase 1.2, donde
# la fecha se armaba solo en memoria y se descartaba.
#
# **Script:** `src/fase1_agregar_columna_fecha.py`
#
# **Por qué persistirla acá y no reconstruirla en cada notebook:** para no
# repetir la misma transformación en cada fase que necesite ordenar u
# agrupar por fecha (Fase 2, Fase 4). Una sola fuente de verdad para la
# columna, calculada una vez.
#
# ⚠️ **Nota:** a diferencia de los pasos anteriores (que solo leían el
# archivo), este script **modifica y sobreescribe**
# `chaco_serie_mensual_2002_2026.csv`. Correrlo una sola vez.
#
# ---

# %%
import os
os.chdir('..')

# %%
# %run src/fase1_agregar_columna_fecha.py
# Out:
# Columna 'fecha' agregada y persistida en: chaco_serie_mensual_2002_2026.csv
# Rango: 2002-01 a 2026-06
# Filas: 884 | Columnas: ['Año', 'Mes', 'FOB_dólar', 'Peso neto', 'Nombre Prov', 'Nombre_Región', 'Rubro', 'fecha']
