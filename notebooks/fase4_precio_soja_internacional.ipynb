# %% [markdown]
# ## Fase 4.4 — Precio implícito de Chaco vs. precio internacional de la soja
#
# **Objetivo:** contrastar el precio implícito de Chaco (Fase 4.1, promedio de
# TODOS los rubros de la provincia) contra el precio de un commodity puntual
# —porotos de soja crudos, a nivel nacional— para ver si el precio
# internacional de referencia explica los movimientos del precio de Chaco.
#
# **Script:** `src/fase4_precio_soja_internacional.py`
#
# **Fuente adicional:** `data/raw/prod_soja_acum_2002_2025.xlsx`, hoja
# `soja_ncm_acum` — complejo soja NACIONAL (sin desglose por provincia).
# Se usan los NCM 12010090 (2002-2011) y 12019000 (2012-2025): mismo
# producto (porotos de soja crudos, excluidos para siembra), códigos
# sucesivos sin superposición — verificado en el propio script antes de sumar.
#
# ⚠️ **Limitación:** este precio es el implícito de exportación *argentina*
# (FOB/kg), no una cotización internacional de pizarra — proxy razonable, no
# fuente primaria. Anotar en `docs/matriz_de_citas.md` si se cita en conclusiones.

# %%
# %run ../src/fase4_precio_soja_internacional.py
# Out:
# ...
# FASE 4.4 — PRECIO IMPLÍCITO DE CHACO vs. PRECIO DE LA SOJA (porotos crudos, nacional)
# ...
#
# Año      Chaco (USD/ton)    Soja (USD/ton)    Δ% Chaco     Δ% Soja   ¿Misma dir.?
# ------------------------------------------------------------------------------------
# 2015               335.4             365.8      -11.5%      -27.7%           ✅ sí
# 2016               281.7             360.1      -16.0%       -1.6%           ✅ sí
# 2017               261.6             368.3       -7.1%       +2.3%           ❌ no
# 2018               338.2             391.5      +29.3%       +6.3%           ✅ sí
# 2019               255.3             338.1      -24.5%      -13.6%           ✅ sí
# 2020               261.1             342.5       +2.3%       +1.3%           ✅ sí
# 2021               367.2             519.9      +40.7%      +51.8%           ✅ sí
# 2022               398.2             594.0       +8.4%      +14.3%           ✅ sí
# ...

# %% [markdown]
# ### 📌 Conclusión parcial — Fase 4.4
#
# Correlación general 2015-2025: 0,86 — en el largo plazo, el precio de Chaco
# sí tiende a acompañar al precio de la soja. Pero en **2024**, el año piso de
# la caída, los dos precios se desacoplan de forma marcada: la soja cayó
# -20,7% mientras el precio implícito de Chaco subió +15,1%. Si el precio
# internacional fuera el motor de la caída 2022-2024, 2024 debería haber sido
# el año de mayor caída de precio en Chaco — ocurrió lo contrario.
#
# Este resultado refuerza el hallazgo de la Fase 4.3 (el volumen domina, no
# el precio) y sugiere que la explicación pasa más por composición de
# productos que por precio internacional. Pendiente: Fase 4.5 (ITCRM, para
# descartar el efecto cambiario) y Fase 4.6 (composición por Rubro).
