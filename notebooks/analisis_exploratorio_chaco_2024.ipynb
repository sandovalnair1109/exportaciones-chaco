# %% [markdown]
# # Análisis exploratorio de microdatos OPEX — Chaco (2024)
#
# **Fuente:** `Datos_origen_2024_mayo_2025.xlsx`, hoja `'Datos Opex Año 2024'`
#
# **Objetivo:** explorar la estructura y contenido del archivo de microdatos para Chaco.

# %%
# %run ../src/analizar_microdatos_chaco_2024.py
# Out:
# ============================================================
# ESTRUCTURA GENERAL DEL ARCHIVO
# ============================================================
# Total de filas:        11014
# Columnas:              ['CANIO', 'CMES', 'PCIA', 'DESCRIP_PCIA', 'CCOD_RUBRO', 'DESCRIP_RUBRO', 'CCOD_PAIS', 'DESCRIP_PAIS', 'DOLARES_FOB', 'PESO_NETO_KG']
# Meses presentes:       [np.int64(12)]
# Años presentes:        [np.int64(2024)]
# Provincias:            27
#
# ============================================================
# CHACO — RESUMEN AGREGADO
# ============================================================
# Filas:                 304
# DOLARES_FOB total:     $402,246,398.09
# PESO_NETO_KG total:    1,187,391,873.97
#
# ============================================================
# CHACO — RUBROS (por DOLARES_FOB)
# ============================================================
# Maíz                                             $   136.83 M  ( 34.0%)
# Soja                                             $    79.56 M  ( 19.8%)
# Extracto de quebracho                            $    46.52 M  ( 11.6%)
# Fibras de algodón                                $    37.91 M  (  9.4%)
# Manufacturas de origen agropecuario (confidencia $    23.86 M  (  5.9%)
# Resto de productos primarios                     $    19.08 M  (  4.7%)
# Trigo                                            $    18.19 M  (  4.5%)
# Sorgo granífero                                  $    15.03 M  (  3.7%)
# Productos primarios (confidencial)               $    10.32 M  (  2.6%)
# Manufacturas de origen industrial (confidencial) $     4.78 M  (  1.2%)
#
# ============================================================
# CHACO — PAÍSES DESTINO (por DOLARES_FOB)
# ============================================================
# China                               $   106.75 M  ( 26.5%)
# Viet Nam                            $    38.26 M  (  9.5%)
# Chile                               $    19.83 M  (  4.9%)
# Perú                                $    19.59 M  (  4.9%)
# Brasil                              $    16.60 M  (  4.1%)
# Paquistán                           $    15.74 M  (  3.9%)
# Italia                              $    14.72 M  (  3.7%)
# Corea, República de                 $    13.69 M  (  3.4%)
# Malasia                             $    13.08 M  (  3.3%)
# México                              $    13.03 M  (  3.2%)
#
# ============================================================
# CHACO — REGISTROS CON RUBRO CONFIDENCIAL
# ============================================================
# Cantidad de filas:48
# Suma DOLARES_FOB:$38,964,078.99
#
# ============================================================
# CHACO — PRECIO PROMEDIO USD/KG (top 5 rubros por valor)
# ============================================================
# Maíz                                     $0.205/kg
# Soja                                     $0.435/kg
# Extracto de quebracho                    $1.652/kg
# Fibras de algodón                        $1.077/kg
# Manufacturas de origen agropecuario (con $1.062/kg
#
# ============================================================
# CHACO — TOP 10 REGISTROS INDIVIDUALES (mayor DOLARES_FOB)
# ============================================================
# Soja                                | China                | $ 74,362,043.71
# Maíz                                | Viet Nam             | $ 26,418,989.37
# Maíz                                | Perú                 | $ 16,874,442.59
# Fibras de algodón                   | Paquistán            | $ 15,578,129.70
# Sorgo granífero                     | China                | $ 14,769,398.53
# Maíz                                | Corea, República de  | $ 12,993,151.46
# Maíz                                | Malasia              | $ 12,317,412.20
# Extracto de quebracho               | México               | $ 12,262,438.75
# Maíz                                | Argelia              | $ 11,188,157.15
# Fibras de algodón                   | Viet Nam             | $  9,549,284.24
