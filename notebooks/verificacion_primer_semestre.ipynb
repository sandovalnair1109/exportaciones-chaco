# %% [markdown]
# ## Paso 4 — Serie mensual oficial: primeros semestres (2002-2026)
#
# **Objetivo:** construir una serie comparable de primer semestre (Ene-Jun) usando la fuente mensual oficial del INDEC, dado que los microdatos 2024 no son confiables por sí solos.
#
# **Script:** `src/verificar_primer_semestre.py`
#
# ---
#
# ### ¿Por qué este paso?
#
# Si el **Paso 3** detectó una discrepancia significativa, descartamos los microdatos parciales y usamos esta serie mensual que cubre **2002-2026** con el mismo criterio de registro en todos los años.
#
# ### Estructura de la salida
#
# | Columna | Descripción |
# |:--------|:------------|
# | **Año** | Año calendario |
# | **USD FOB (millones)** | Suma del semestre en millones de dólares FOB |
# | **Toneladas** | Suma del semestre en toneladas métricas |
#
# ### Uso metodológico
#
# - Permite comparar **2024 vs. años anteriores** en ventana de primer semestre.
# - Evita el sesgo de cobertura parcial de los microdatos.
# - Base para análisis de tendencia, estacionalidad y proyección.
#
# ---

# %%
# %run ../src/verificar_primer_semestre.py
# Out:
# ...
# PASO 4 — PRIMER SEMESTRE (Ene-Jun) | Serie mensual oficial INDEC
# Provincia: Chaco
# Fuente: Serie_Opex_Mensual_2002_2026.xlsx
# Hoja:   Serie_Opex_Mensual_2002_2026_06
# ...
#
# Año          USD FOB (millones)            Toneladas
# ------------------------------------------------------
# 2002                       78.9              430,497
# 2003                      122.7              655,477
# 2004                       86.2              373,226
# 2005                       79.4              328,451
# 2006                       98.0              450,327
# 2007                      127.5              539,613
# 2008                      180.2              568,821
# 2009                       88.9              258,907
# 2010                      174.5              548,331
# 2011                      257.6              605,446
# 2012                      149.8              354,472
# 2013                      155.7              364,854
# ...
